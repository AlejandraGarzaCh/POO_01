# %% [markdown]
# ## Examen
#
# * Es necesario seguir los lineamientos ya preestablecidos.
#
# * Habrá cero tolerancia al plagio.
#
# * Sólo podrás hacer uso de las libretas que tengas, no se permite el uso de ChatGPT.
#
# * Todas las soluciones deben presentarse de manera lógica. Se penalizará la ausencia de argumentos y de documentación.

# %% [markdown]
# **Ejercicio 1:**
#
# ¿Qué es una clase y por qué es útil? \\
# Define una clase con un ejemplo, dando todas sus características.
#
# ---

# %% [markdown]
# Una clase es configuración en programacion que nos deja definir una agrupacion de atributos y métodos, los cuales describen un objeto o entidad. Es útil ya que puedes descomponer el programa en partes chicas, puedes utilizar el código cuantas veces quieras y te ahorra mucho tiempo.

# %%
#Ejemplo de una clase
class Pais1:
    def __init__(self):
        self.nombre = "España"
        self.capital = "Madrid"
        self.idioma = "Español"

#Esta clase se llama Pais1, tiene una definición la cual es un constructor ya que esta definida como "def__init__(self):". Esta clase tiene 3 parámetros los cuales son el nombre del país "España",la capital del país "Madrid" y el idioma del país el cual es "Español".

# %% [markdown]
# **Ejercicio 2:**
#
# En Python, un **constructor** es un método especial que se llama automáticamente cuando se crea un objeto. Se utiliza para inicializar los atributos del objeto y realizar cualquier tarea de configuración necesaria antes de su uso. \\
#
# Para este ejercicio contesta las siguientes preguntas:
#
#
# 1.   ¿Cuál es la sintaxis para definir un constructor dentro de una clase?
# 2.   Considera el siguiente código: \\
#
# ![constructor.png](data:image/png;base64,...)
#
# \\
# La clase 'Human' tiene un constructor que toma dos parametros, ¿cuáles son?

# %% [markdown]
# 1. La sintaxis para definir un constructor dentro de una clase tiene que ser la primera definición que se pone dentro de la clase. Para que sea el constructor debes de poner "def ___init__" forzosamente, seguido del parentesis en donde pondrás las variables que se utilizarán y dos puntos ":" al final.
#
# 2. La clase Human tiene dos parámetros que son self.legs cuyo valor es 2, y self.arms cuyo valor es 2 también.

# %% [markdown]
# 3. Crea dos atributos (definiciones y polimorfismos) asociados a la clase 'Human´.
#
# ---

# %%
class Human:
  def __init__(self):
    self.legs = 2
    self.arms = 2
  def nombre(self):
    self.nombre = "alejandra"
  def edad(self):
    self.edad = 21

# %% [markdown]
# **Ejercicio 3:**
#
# Indica si las siguientes afirmaciones son verdaderas o falsas:
#
#
#
# *   El primer parámetro del método '__ init() __' es siempre 'self' , que se refiere a la instancia de la clase que se está creando. Se pasa automáticamente al constructor cuando se instancia el objeto.
# *   Después de 'self', puedes definir cualquier otro parámetro necesario para inicializar los atributos del objeto.
# *   Cuando añades la función '__ init ()  __' , la clase heredada ya no hereda la función ' __ init () __ ' de la clase madre.
# *   En la programación orientada a objetos, las clases pueden heredar atributos y métodos de otras clases.
# *  Cuando hablamos de polimorfismos en Python, diferentes clases pueden ser tratadas como instancias de la misma superclase, independientemente de cómo implementen el mismo método.
#
# ---

# %% [markdown]
# 1. Verdadero ya que poniendo 'self' estas indicando la instancia de la clase.
# 2. Verdadero ya que si no pones otro parámetro no le estas indicando que utilice algun otro parámetro mas que self.
# 3. Falso la clase heredada si toma la función "__init()" de la clase madre
# 4. Verdadero, el principal objetivo de las clases es poder heredar definiciones y atributos de otras clases.
# 5. Verdadero ya que de la clase mater te puedes traer instancias.

# %% [markdown]
# **Ejercicio 4:** A partir de un diccionario, crea un DataFrame (que llamarás **precios_muestra**) que consista de dos columnas y que tenga 12 valores **flotantes** que eligirás de manera aleatoria en el intervalo (8,13). Etiqueta del 1 al 12 y llama a la columna de etiquetas Mes.
#
# 1.- Construye una función que calcule los rendimientos simples de cada columna.
#
# 2.- Las desviaciones estadísticas de los rendimientos ayudan a calcular la volatilidad del portafolio:
# $$\text{desviaciones}=(\text{rendimientos}-\text{media}(\text{rendimientos}))^2.$$
# Crea una función que calcule la media de las desviaciones y luego la volatilidad de tu portafolio (raíz cuadrada de la media de las desviaciones).
#
# 3.- Anualizamos la volatilidad escalándola (multiplicándola) por la raíz cuadrada del número de períodos por observación.
#
# Por lo tanto, para anualizar la volatilidad de una serie mensual, la multiplicamos por la raíz cuadrada de 12. Muestra la serie de la volatilidad anualizada.
#
# 4.- Realiza una gráfica de barras para los rendimientos y una gráfica en líneas para los precios.
#
# 5.- Calcula los rendimientos compuestos para cada columna y después anualiza los rendimientos.
#
# ---

# %%
import pandas as pd
import random

#12 Valores flotantes aleatorios en el intervalo (8,13)
vf_random = [random.uniform(8, 13) for _ in range(12)]

#Diccionario
diccionario = {'Mes': list(range(1, 13)),
        'Precios': vf_random}

#Conversión a data frame
precios_muestra = pd.DataFrame(diccionario)
print(precios_muestra)
# Out:
#     Mes    Precios
# 0     1   9.383967
# 1     2  10.987138
# 2     3   9.625477
# 3     4   8.360925
# 4     5  10.527195
# 5     6  10.112856
# 6     7  10.276761
# 7     8  11.623513
# 8     9  11.283920
# 9    10   9.007481
# 10   11   8.760740
# 11   12   9.917851

# %%
#Rendimientos simples únicamente de la columan de los precios
rendimientos_simples = precios_muestra["Precios"].pct_change().dropna()
rendimientos_simples
# Out:
# 1     0.170842
# 2    -0.123932
# 3    -0.131376
# 4     0.259095
# 5    -0.039359
# 6     0.016208
# 7     0.131048
# 8    -0.029216
# 9    -0.201742
# 10   -0.027393
# 11    0.132079
# Name: Precios, dtype: float64

# %%
#Desviaciones Estadísticas
#Fórmula desviaciones=(rendimientos−media(rendimientos))2

#Promedio de rendimientos simples
rendimientos_simples_promedio = rendimientos_simples.mean()
rendimientos_simples_promedio
# Out:
# 0.014204875108733512

# %%
#Función para "rendimientos−media(rendimientos)"
rendimientos_simples.std()
# Out:
# 0.0

# %%
#Volatilidad Anualizada
from math import sqrt
volatilidad_anualizada = rendimientos_simples.std() * sqrt(12)
volatilidad_anualizada
# Out:
# 0.0

# %%
#Rendimientos Compuesto
rendimiento_compuesto = (rendimientos_simples + 1).prod() - 1
rendimiento_compuesto
# Out:
# 0.014204875108733583

# %%
#Rendimientos Compuesto Anualizado
rendimiento_compuesto_anualizado = rendimiento_compuesto * sqrt(12)
rendimiento_compuesto_anualizado
# Out:
# 0.04920713080699409

# %%
#Gráfica de barras para los rendimientos y grafica de lineas para los precios

# %% [markdown]
# **Ejercicio 5:** Carga dos tickers y realiza los pasos del ejercicio anterior usando los tickers que elijas. Recuerda tomar en cuenta la ventana de tiempo que manejarás. Realiza un análisis estadístico (estadística descriptiva, histogramas y gráficas de series de tiempo).

# %%
#Clase Financiera
from datetime import datetime

import yfinance as yf

class Asset:
    def __init__(self, ticker, start_date,
                 end_date = datetime.today().strftime('%Y-%m-%d')):
        self.ticker = ticker
        self.start_date = start_date
        self.end_date = end_date

    def get_data(self):
        df = yf.download(self.ticker, start = self.start_date, end = self.end_date)
        return df

    def simple_returns(self, adj = False, cum = False):
        df = self.get_data()
        if adj:
            simple_returns = df["Adj Close"].pct_change().dropna()
        else:
            simple_returns = df["Close"].pct_change().dropna()
        if cum:
            simple_returns = (1 + simple_returns).cumprod() - 1
        return simple_returns
    def rendimiento_compuesto (rendimientos):
        return (rendimientos + 1).prod() - 1
    def anualizar(rend_periodo, periodos_por_año):
        return (1 + rend_periodo)**periodos_por_año - 1

# %%
#Importe de lo datos del ticker "VZ"
from datetime import datetime
import yfinance as yf
vz = Asset("VZ", "2022-1-1", "2023-1-1")
vz.get_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-01-03  52.070000  52.560001  51.980000  52.439999  46.316528  18240100
# 2022-01-04  52.639999  53.709999  52.549999  53.470001  47.226257  26376800
# 2022-01-05  53.840000  54.639999  53.509998  54.020000  47.712036  28697300
# 2022-01-06  54.480000  54.549999  53.660000  53.759998  47.482391  21563800
# 2022-01-07  53.259998  54.360001  53.259998  54.240002  48.483528  26512500
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  38.310001  38.540001  37.919998  38.410000  35.781872  16918300
# 2022-12-27  38.490002  39.400002  38.320000  39.250000  36.564396  25315900
# 2022-12-28  39.189999  39.660000  38.590000  38.810001  36.154499  21793200
# 2022-12-29  38.900002  39.529999  38.810001  39.259998  36.573711  17347000
# ...

# %%
#Rendimientos simples del ticker "VZ"
import numpy as pd
import pandas as pd
vz.simple_returns()
simple_returns_vzdf = pd.DataFrame(vz.simple_returns())
simple_returns_vzdf
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                Close
# Date
# 2022-01-04  0.019642
# 2022-01-05  0.010286
# 2022-01-06 -0.004813
# 2022-01-07  0.008929
# 2022-01-10 -0.006822
# ...              ...
# 2022-12-23  0.002610
# 2022-12-27  0.021869
# 2022-12-28 -0.011210
# 2022-12-29  0.011595
# 2022-12-30  0.003566
#
# [250 rows x 1 columns]

# %%
#Rendimientos compuestos del ticker "VZ"
import numpy as np
(simple_returns_vzdf + 1).prod() - 1
# Out:
# Close   -0.248665
# dtype: float64

# %%
#Función para "rendimientos−media(rendimientos)"
simple_returns_vzdf.std()
# Out:
# Close    0.014393
# dtype: float64

# %%
#Volatilidad Anualizada
from math import sqrt
volatilidad_anualizada_vz = simple_returns_vzdf.std() * sqrt(250)
volatilidad_anualizada_vz
# Out:
# Close    0.227573
# dtype: float64

# %%
#Importe de lo datos del ticker "GE"
from datetime import datetime
import yfinance as yf
ge = Asset("GE", "2022-1-1", "2023-1-1")
ge.get_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-03  74.332550  76.065575  73.965652  75.128807  74.628464  5917964
# 2022-01-04  77.111633  78.103043  76.572990  77.572212  77.055588  9766472
# 2022-01-05  77.853241  79.461357  77.509758  77.572212  77.055588  7551111
# 2022-01-06  78.415298  78.907104  77.611244  78.024979  77.505333  5478837
# 2022-01-07  77.907883  79.812645  77.884468  79.156906  78.629730  8004072
# ...               ...        ...        ...        ...        ...      ...
# 2022-12-23  63.786106  64.316940  63.200626  63.848557  63.696453  4218845
# 2022-12-27  64.012489  64.863388  63.934425  64.668228  64.514175  5430800
# 2022-12-28  64.785324  64.925842  63.466042  63.989071  63.836632  4956830
# 2022-12-29  64.207649  65.503510  64.012489  65.378609  65.222862  5657408
# ...

# %%
#Rendimientos simples del ticker "GE"
import numpy as pd
import pandas as pd
ge.simple_returns()
simple_returns_gedf = pd.DataFrame(ge.simple_returns())
simple_returns_gedf
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                Close
# Date
# 2022-01-04  0.032523
# 2022-01-05  0.000000
# 2022-01-06  0.005837
# 2022-01-07  0.014507
# 2022-01-10 -0.019527
# ...              ...
# 2022-12-23  0.000245
# 2022-12-27  0.012838
# 2022-12-28 -0.010502
# 2022-12-29  0.021715
# 2022-12-30  0.000478
#
# [250 rows x 1 columns]

# %%
#Función para "rendimientos−media(rendimientos)"
simple_returns_gedf.std()
# Out:
# Close    0.022022
# dtype: float64

# %%
#Volatilidad Anualizada
from math import sqrt
volatilidad_anualizada_ge = simple_returns_gedf.std() * sqrt(250)
volatilidad_anualizada_ge
# Out:
# Close    0.348206
# dtype: float64

# %%
#Rendimientos compuestos del ticker "GE"
import numpy as np
(simple_returns_gedf + 1).prod() - 1
# Out:
# Close   -0.129364
# dtype: float64

# %%
#Histograma de los rendimientos simples de cada ticker
import matplotlib.pyplot as plt

# Datos de ejemplo
plt.figure(figsize=(12, 6))
plt.hist(simple_returns_vzdf, bins=50, alpha=0.5, label="AMZN")
plt.hist(simple_returns_gedf, bins=50, alpha=0.5, label="KO")
plt.xlabel("Rendimiento Simple")
plt.ylabel("Frecuencia")
plt.legend()
plt.title("Histograma de Rendimientos Simples")
plt.show()

# %%
#Graficar serie de tiempo de VZ
#VZ
start = "2022-1-1"
end = "2023-01-01"

vz_seriedetiempo = yf.download("VZ", start, end)
vz_seriedetiempo
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-01-03  52.070000  52.560001  51.980000  52.439999  46.316532  18240100
# 2022-01-04  52.639999  53.709999  52.549999  53.470001  47.226261  26376800
# 2022-01-05  53.840000  54.639999  53.509998  54.020000  47.712029  28697300
# 2022-01-06  54.480000  54.549999  53.660000  53.759998  47.482384  21563800
# 2022-01-07  53.259998  54.360001  53.259998  54.240002  48.483532  26512500
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  38.310001  38.540001  37.919998  38.410000  35.781872  16918300
# 2022-12-27  38.490002  39.400002  38.320000  39.250000  36.564396  25315900
# 2022-12-28  39.189999  39.660000  38.590000  38.810001  36.154503  21793200
# 2022-12-29  38.900002  39.529999  38.810001  39.259998  36.573711  17347000
# ...

# %%
vz_seriedetiempo["Adj Close"]
# Out:
# Date
# 2022-01-03    46.316532
# 2022-01-04    47.226261
# 2022-01-05    47.712029
# 2022-01-06    47.482384
# 2022-01-07    48.483532
#                 ...
# 2022-12-23    35.781872
# 2022-12-27    36.564396
# 2022-12-28    36.154503
# 2022-12-29    36.573711
# 2022-12-30    36.704132
# Name: Adj Close, Length: 251, dtype: float64

# %%
vz_seriedetiempo["Adj Close"].plot(label="VZ", figsize = (15,8))
# Out:
# <Axes: xlabel='Date'>

# %%
#Graficar serie de tiempo de GE
#VZ
start = "2022-1-1"
end = "2023-01-01"

ge_seriedetiempo = yf.download("GE", start, end)
ge_seriedetiempo
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-03  74.332550  76.065575  73.965652  75.128807  74.628448  5917964
# 2022-01-04  77.111633  78.103043  76.572990  77.572212  77.055588  9766472
# 2022-01-05  77.853241  79.461357  77.509758  77.572212  77.055588  7551111
# 2022-01-06  78.415298  78.907104  77.611244  78.024979  77.505356  5478837
# 2022-01-07  77.907883  79.812645  77.884468  79.156906  78.629723  8004072
# ...               ...        ...        ...        ...        ...      ...
# 2022-12-23  63.786106  64.316940  63.200626  63.848557  63.696453  4218845
# 2022-12-27  64.012489  64.863388  63.934425  64.668228  64.514175  5430800
# 2022-12-28  64.785324  64.925842  63.466042  63.989071  63.836632  4956830
# 2022-12-29  64.207649  65.503510  64.012489  65.378609  65.222862  5657408
# ...

# %%
ge_seriedetiempo["Adj Close"]
# Out:
# Date
# 2022-01-03    74.628448
# 2022-01-04    77.055588
# 2022-01-05    77.055588
# 2022-01-06    77.505356
# 2022-01-07    78.629723
#                 ...
# 2022-12-23    63.696453
# 2022-12-27    64.514175
# 2022-12-28    63.836632
# 2022-12-29    65.222862
# 2022-12-30    65.254013
# Name: Adj Close, Length: 251, dtype: float64

# %%
ge_seriedetiempo["Adj Close"].plot(label="GE", figsize = (15,8))
# Out:
# <Axes: xlabel='Date'>
